# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv("../data/steam_games_feature.csv")
df.head()
# Out:
#                     Name Release date Estimated owners  Peak CCU  \
# 0       Galactic Bowling   2008-10-21        0 - 20000         0
# 1           Train Bandit   2017-10-12        0 - 20000         0
# 2           Jolt Project   2021-11-17        0 - 20000         0
# 3               Henosis™   2020-07-23        0 - 20000         0
# 4  Two Weeks in Painland   2020-02-03        0 - 20000         0
#
#    Required age  Price  DLC count  \
# 0             0  19.99          0
# 1             0   0.99          0
# 2             0   4.99          0
# 3             0   5.99          0
# 4             0   0.00          0
#
#                                  Supported languages Full audio languages  \
# 0                                        ['English']                   []
# 1  ['English', 'French', 'Italian', 'German', 'Sp...                   []
# 2                 ['English', 'Portuguese - Brazil']                   []
# 3  ['English', 'French', 'Italian', 'German', 'Sp...                   []
# 4                     ['English', 'Spanish - Spain']                   []
#
#    Windows  ...  review_count  review_balance  price_log  owners_log  is_free  \
# 0     True  ...            17       -0.277778   3.044046     9.21044        0
# 1     True  ...            58        0.813559   0.688135     9.21044        0
# 2     True  ...             0        0.000000   1.790091     9.21044        0
# 3     True  ...             3        0.750000   1.944481     9.21044        0
# 4     True  ...            58        0.711864   0.000000     9.21044        1
#
#    main_genre  main_category  rating_gap  release_decade  is_recent
# 0      Casual  Single-player           0            2000          0
# 1      Action  Single-player           0            2010          0
# 2      Action  Single-player           0            2020          1
# 3   Adventure  Single-player           0            2020          1
# 4   Adventure  Single-player           0            2020          1
#
# [5 rows x 45 columns]

# %%
# 目標變數（owners_log）
target = "owners_log"

y = df[target]

# Baseline 不需要 X，但 train/test split 還是要做
X_dummy = df[[target]]  # 只是為了符合 sklearn 的 split API

X_train, X_test, y_train, y_test = train_test_split(
    X_dummy, y, test_size=0.2, random_state=42
)

print("Train size:", len(y_train))
print("Test size:", len(y_test))
# Out:
# Train size: 66273
# Test size: 16569

# %%
# Baseline: 用訓練集 y 的平均來預測所有 test 樣本
baseline_pred = np.full_like(y_test, y_train.mean(), dtype=float)

baseline_pred[:5]
# Out:
# array([8.51859413, 8.51859413, 8.51859413, 8.51859413, 8.51859413])

# %%
baseline_mae = mean_absolute_error(y_test, baseline_pred)
baseline_rmse = np.sqrt(mean_squared_error(y_test, baseline_pred))
baseline_r2 = r2_score(y_test, baseline_pred)

print("=== Baseline Model Performance ===")
print(f"MAE  : {baseline_mae:.4f}")
print(f"RMSE : {baseline_rmse:.4f}")
print(f"R²   : {baseline_r2:.4f}")
# Out:
# === Baseline Model Performance ===
# MAE  : 2.1947
# RMSE : 3.4451
# R²   : -0.0001
